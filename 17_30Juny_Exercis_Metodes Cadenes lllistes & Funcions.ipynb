# %%
# Mètode 1 - if "arbre de decisió"
verb = input("Entra un verb")
if verb.endswith("ar")
    print(f"{verb} -> 1'{verb}'")
else:

    if verb.endswith("re") or verb.endswith("er")
            print(f"{verb} -> 2'{verb}'")
    else:

          if verb.endswith("ir")
              print(f"{verb} -> 3'{verb}'")
          else:
              print(f"{verb} -> '{verb}' no te conjugació")

# %%
# Mètode 2  - if exclusivo
verb = input("Entra un verb")
if verb.endswith("ar")
    print(f"{verb} -> 1'{verb}'")

elif verb.endswith("re") or verb.endswith("er")
    print(f"{verb} -> 2'{verb}'")

elif verb.endswith("ir")
    print(f"{verb} -> 3'{verb}'")

else:
    print(f"{verb} -> '{verb}' no te conjugació")

# %%
# Mètode 3 - Menys eficient pq fa tots els if cada vegada
verb = input("Entra un verb")

if verb.endswith("ar")
    print(f"{verb} -> 1'{verb}'")

if verb.endswith("re") or verb.endswith("er")
    print(f"{verb} -> 2'{verb}'")

if verb.endswith("ir")
    print(f"{verb} -> 3'{verb}'")

else:
    print(f"{verb} -> '{verb}' no te conjugació")
# Out:
#   File "/tmp/ipython-input-4-2245449408.py", line 4
#     print(f"{verb} -> 1'{verb'"})
#                                ^
# SyntaxError: closing parenthesis '}' does not match opening parenthesis '('

# %%
# Mètode 4  - Si no acaba amb ar, re, er, ir, demana que torni a intrudir el ver
verb = input("Entra un verb per saber quin tipus de conjugació té:")

while verb.isalpha() == False or (verb.endswith("ar") and not verb.endswith("re") and not verb.endswith("er") and not verb.endswith("ir")):
       verb = input("Siusplau entra un verb sense espais i amb caracters alfabètics: i que acabi amb AR, RE, ER, o IR:")

if  verb.endswith("ar"):
    print(f"{verb} -> 1'{verb}'")

elif  verb.endswith("re") or verb.endswith("er"):
    print(f"{verb} -> 2'{verb}'")

else:
    print(f"{verb} -> 3'{verb}'")
# Out:
# Entra un verb per saber quin tipus de conjugació té:asfasfasf     asfasffir
# Siusplau entra un verb sense espais i amb caracters alfabètics: i que acabi amb AR, RE, ER, o IR:asdasdd ir
# Siusplau entra un verb sense espais i amb caracters alfabètics: i que acabi amb AR, RE, ER, o IR:asdasdasdasdir
# asdasdasdasdir -> 3'asdasdasdasdir'

# %%
 # str es un tipo de dato inmutable pero permite la asignació

 cadena = "245,345"

 print(cadena.replace(",",""), cadena)

 temp = int(cadena.replace(",", ""))

 print(temp + 1, type(temp))

 cadena = cadena.replace(",", "")
 cadena = cadena +"1"

print(cadena, type(cadena))
# Out:
# 245345 245,345
# 245346 <class 'int'>
# 2453451 <class 'str'>

# %% [markdown]
# MÈTODES A LLISTES
#
#
# ```
# llista = []
# llista[0] ----------llista[len(cadena)-1]
# llista[-1] ----------llista[-len(cadena)]
# llista[2:] llista[2: 6] llista2=llista1 llista2=llista1[:]
# OjO : 6 -> 5
#
# llista[:2] llista[1: len(llista-2)]
#
# llista2=llista1 # Malament
# llista2=llista1[:]  # Correcte
#
#
# ```
# 3.1 MESURES DE LES LLISTES
# ```
# len(llista) # Longitud d’una llista
# max(llista) #valor més gran d’una llista
# min(llista) #Valor més petit d’una llista
# ```
#
# 3.4 AFEGIR ELEMENTS A UNA LLISTA
#
#
#
# ```
# llista.append(element) -----Afegir element al final de la llista.
# llista.insert(index, element) ----- Afegir element abans d'index.
# llista1.extend(llista2) ------ El resultat equival a llista1 + llista2
#
# ```
#
# 3.5 ELIMINAR ELEMENTS D'UNA LLISTA
#
#
#
#
# ```
# llista.clear() ----- Buida totalment una llista
# llista.remove(valor) -----Elimina la primera aparició
# primera aparició d'un element i dóna Value
# Error si el valor no és present.
# llista.pop(index) ----- Elimina l'element que es
# troba en un índex concret. Dóna
# Indexerror si la llista és buida o l'índex
# no existeix a la llista.
# ```

# %%
# Mètodes Llistes

llista = [1, 2, 3, 4, 5, 6, 7, 8, 9]
llistemp1 = llista.copy()
llistemp2 = llista.copy()
try:
    llistemp1.remove(10)   # Elimina la posición / ojo si no ho troba peta el programa
except ValueError:
    if ValueError:
        llistemp1=['ValueError']
    pass

try:
    llistemp2.pop(10)      # Elimina la posición
except IndexError:
    if IndexError:
        llistemp2=['IndexError']
    pass

print(f"'Original:'{llista} \n 'llista remove:' {llistemp1} \n 'llista pop:' {llistemp2}")
# Out:
# 'Original:'[1, 2, 3, 4, 5, 6, 7, 8, 9]
#  'llista remove:' ['ValueError']
#  'llista pop:' ['IndexError']

# %% [markdown]
# Ojo El colab i las funciones

# %%
def empiezacon(s, caracter):
    return s[0] == caracter

def empiezacon_2(s, caracter):
    print(s[0] == caracter, "dentro empiezacon_2")

ciudad = "Barcelona"
letra = "A"

empiezacon(ciudad, letra)
# Out:
# False

# %%
def empiezacon(s, caracter):
    return s[0] == caracter

def empiezacon_2(s, caracter):
    print(s[0] == caracter, "dentro empiezacon_2")

ciudad = "Barcelona"
letra = "A"

empiezacon(ciudad, letra)

print(empiezacon(ciudad, letra), ": con orden imprimir funcion CON return")

empiezacon_2(ciudad, letra)

print(empiezacon_2(ciudad, letra),": con orden imprimir funcion SIN return")
# Out:
# False : con orden imprimir funcion CON return
# False dentro empiezacon_2
# False dentro empiezacon_2
# None : con orden imprimir funcion SIN return
