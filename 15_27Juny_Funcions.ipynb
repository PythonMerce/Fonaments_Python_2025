# %% [markdown]
# Definint Funciones:

# %%
def empiezacon(cadena, caracter):

    return cadena[0] == caracter

cadena = "Barcelona"

# Funcio nova definida "empiezacon"
print('Resultat de la funció nova creada: ', empiezacon(cadena, "B"))

print(cadena.startswith("B"))
#
# Out:
# Resultat de la funció nova creada:  True
# True

# %%
cadena = "Barcelona"
caracter = "B"
a = False
b = False
def tomando(cad, car):
    return cad[0] == car, cad[1] == car # Return un tupple de booleans
a,b = tomando(cadena,caracter)

print(f"a: {a}, b: {b}")
# Out:
# a: True, b: False

# %%
cadena = "Barcelona"
caracter = "B"
a = False
b = False
def tomando(cad, car):
    return cad[0] == car, 1+3, cad[0] != car  # Return un tupple
a, b, c = tomando(cadena,caracter)

print(f"a: {a}, b: {b}, c: {c}")
# Out:
# a: True, b: 4, c: False

# %% [markdown]
# **Exercicis de Cadenes:**
#
# 4. Comptar paraules:
# Compta el número de paraules que hi ha dins d'una cadena de text que li passeu per paràmetre (les
# paraules sempre estan separades per un o més espais en blanc)
#
# 14. Escriu un programa que donada una cadena ens digui si és un palíndrom o no. Una frase o
# cadena és palíndroma si es pot llegir en ordre o a l'inrevés obtenint la mateixa frase, per exemple:
# "dabale arroz a la zorra el abad", és palíndroma.
