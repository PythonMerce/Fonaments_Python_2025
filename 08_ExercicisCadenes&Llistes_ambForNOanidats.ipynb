# %% [markdown]
# Exercicis amb cadenes i llistes usant for (no anidats)
#
# 1.-Mostra cada lletra d’una paraula en una línia diferent.
#
# Exemple: 'Barcelona' →
# B
# a
# r ...
#
# 2.-Compta quantes vocals hi ha en una cadena.
#
# Exemple: 'informàtica' → 5 vocals
#
# 3.-Imprimeix tots els elements d’una llista de noms en majúscules.
#
# Exemple: ['Anna', 'Joan', 'Pau'] → 'ANNA', 'JOAN', 'PAU'
#
# 4.-Concatena els elements d’una llista de paraules separant-los per espais.
#
# Exemple: ['bon', 'dia', 'a', 'tothom'] → 'bon dia a tothom'
#
# 5.-Compta quants números parells hi ha en una llista.
#
# Exemple: [2, 5, 6, 7, 10] → 3 parells
#
# 6.-Multiplica per 2 cada element d’una llista de nombres enters i mostra el resultat.
#
# Exemple: [1, 2, 3] → 2, 4, 6
#
# 7.-Imprimeix només les paraules d’una llista que tinguin més de 4 lletres.
#
# Exemple: ['sol', 'ordinador', 'llum', 'pantalla'] → 'ordinador', 'pantalla'
#
# 8.-Mostra la suma dels dígits d’una cadena numèrica.
#
# Exemple: '1234' → 1 + 2 + 3 + 4 = 10
#
# 9.-Mostra quants elements d’una llista són cadenes (no nombres).
#
# Exemple: [5, 'hola', 7, 'adéu'] → 2 cadenes
#
# 10.-Crea una nova llista amb la longitud de cada paraula d’una llista original.
#
# Exemple: ['sol', 'cel', 'galàxia'] → [3, 3, 7]
#
# resolució amb ChatGPT
# Perfecte! Aquí tens la resolució dels 10 exercicis en Python, un per un, utilitzant només un bucle for (sense bucles anidats):
#
# 1. Mostrar cada lletra d’una paraula en una línia diferent:
#
# paraula = "Barcelona"
# for lletra in paraula:
# print(lletra)
#
# 2. Comptar quantes vocals hi ha en una cadena:
#
# text = "informàtica"
# vocals = "aeiouàèéíòóú"
# comptador = 0
# for lletra in text:
# if lletra.lower() in vocals:
# comptador += 1
# print("Nombre de vocals:", comptador)
#
# 3. Imprimir els noms en majúscules:
#
# noms = \["Anna", "Joan", "Pau"]
# for nom in noms:
# print(nom.upper())
#
# 4. Concatenar paraules amb espais:
#
# paraules = \["bon", "dia", "a", "tothom"]
# frase = ""
# for paraula in paraules:
# frase += paraula + " "
# print(frase.strip())
#
# 5. Comptar números parells en una llista:
#
# numeros = \[2, 5, 6, 7, 10]
# comptador = 0
# for num in numeros:
# if num % 2 == 0:
# comptador += 1
# print("Nombre de parells:", comptador)
#
# 6. Multiplicar per 2 cada element:
#
# valors = \[1, 2, 3]
# for v in valors:
# print(v \* 2)
#
# 7. Mostrar paraules amb més de 4 lletres:
#
# paraules = \["sol", "ordinador", "llum", "pantalla"]
# for paraula in paraules:
# if len(paraula) > 4:
# print(paraula)
#
# 8. Sumar dígits d'una cadena numèrica:
#
# cadena = "1234"
# suma = 0
# for digit in cadena:
# suma += int(digit)
# print("Suma de dígits:", suma)
#
# 9. Comptar quantes cadenes hi ha a la llista:
#
# elements = \[5, "hola", 7, "adéu"]
# comptador = 0
# for element in elements:
# if isinstance(element, str):
# comptador += 1
# print("Nombre de cadenes:", comptador)
#
# 10. Longitud de cada paraula:
#
# paraules = \["sol", "cel", "galàxia"]
# llargades = \[]
# for paraula in paraules:
# llargades.append(len(paraula))
# print(llargades)
#
# Vols que els empaqueti tots en un sol arxiu o vols afegir inputs per fer-los interactius?

# %%
# 1.-Mostra cada lletra d’una paraula en una línia diferent.
cadena = input(str('Introdueix una paraula per imprimir: '))
for posicio in cadena:
  print(posicio)
# Out:
# indtrodueix una paraula per comptar les vocals que conté: oiupiui
# o
# i
# u
# p
# i
# u
# i

# %%
# 2.-Compta quantes vocals hi ha en una cadena.

cadena = input(str('Introdueix una paraula per comptar les vocals que conté: '))
comptador = 0
vocals = "aeiouAEIOUàáèéìíòóùú"
for posicio in cadena:
    if posicio in vocals:
      comptador += 1
print("el nombre de vocals del texte introduït: ", cadena, "és: ", comptador )
# Out:
# indtrodueix una paraula per comptar les vocals que conté: nmjsb
# el nombre de vocals del texte introduït:  nmjsb és:  0

# %%
#3.-Imprimeix tots els elements d’una llista de noms en majúscules.
# noms = \["Anna", "Joan", "Pau"]
noms = ['Anna', 'Joan', 'Pau']
for nom in noms:
print(noms.upper())
# Out:
#   File "/tmp/ipython-input-2-2926744611.py", line 5
#     print(noms.upper())
#     ^
# IndentationError: expected an indented block after 'for' statement on line 4

# %%
dir(list)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
# 4.-Concatena els elements d’una llista de paraules separant-los per espais.
# Exemple: ['bon', 'dia', 'a', 'tothom'] → 'bon dia a tothom'

llistaconca = ['bon', 'dia', 'a', 'tothom']

# %%
# 5.-Compta quants números parells hi ha en una llista.
# Exemple: [2, 5, 6, 7, 10] → 3 parells

# %%
# 6.-Multiplica per 2 cada element d’una llista de nombres enters i mostra el resultat.
# Exemple: [1, 2, 3] → 2, 4, 6

# %%
# 7.-Imprimeix només les paraules d’una llista que tinguin més de 4 lletres.
# Exemple: ['sol', 'ordinador', 'llum', 'pantalla'] → 'ordinador', 'pantalla'
